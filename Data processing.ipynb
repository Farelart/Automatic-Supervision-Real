# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('comportement normal_clean.csv')
df.head()
# Out:
#   Unnamed: 0           Unnamed: 1                 Unnamed: 2      Unnamed: 3  \
# 0      Temps  puisance de chauffe  puissance de prechauffage  Taux de reflux
# 1          0                    0                        100               0
# 2         11                    0                        100               0
# 3         22                    0                        100               0
# 4         33                    0                        100               0
#
#            Unnamed: 4         Unnamed: 5                 Unnamed: 6  \
# 0  Débit alimentation  Pertes de charges  Température de préchauffe
# 1                   0                0.1                        6.9
# 2                   0                0.1                        6.8
# 3                   0                0.1                        6.8
# 4                   0                0.1                        6.9
#
#               Unnamed: 7                   Unnamed: 8
# ...

# %%
df.set_axis(df.iloc[1].tolist(), axis=1,inplace=True)

# %%
df.head()
# Out:
#        0                    0                        100               0  \
# 0  Temps  puisance de chauffe  puissance de prechauffage  Taux de reflux
# 1      0                    0                        100               0
# 2     11                    0                        100               0
# 3     22                    0                        100               0
# 4     33                    0                        100               0
#
#                     0                0.1                        6.9  \
# 0  Débit alimentation  Pertes de charges  Température de préchauffe
# 1                   0                0.1                        6.9
# 2                   0                0.1                        6.8
# 3                   0                0.1                        6.8
# 4                   0                0.1                        6.9
#
#                       15                         16.9
# 0  Température bouilleur  Température tête de colonne
# ...

# %%
df.set_axis(df.iloc[0].tolist(), axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temps  puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0  Temps  puisance de chauffe  puissance de prechauffage  Taux de reflux
# 1      0                    0                        100               0
# 2     11                    0                        100               0
# 3     22                    0                        100               0
# 4     33                    0                        100               0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0  Débit alimentation  Pertes de charges  Température de préchauffe
# 1                   0                0.1                        6.9
# 2                   0                0.1                        6.8
# 3                   0                0.1                        6.8
# 4                   0                0.1                        6.9
#
#    Température bouilleur  Température tête de colonne
# 0  Température bouilleur  Température tête de colonne
# ...

# %%
df.drop(index=0,inplace=True)

# %%
df.head()
# Out:
#   Temps puisance de chauffe puissance de prechauffage Taux de reflux  \
# 1     0                   0                       100              0
# 2    11                   0                       100              0
# 3    22                   0                       100              0
# 4    33                   0                       100              0
# 5    44                 100                       100              0
#
#   Débit alimentation Pertes de charges Température de préchauffe  \
# 1                  0               0.1                       6.9
# 2                  0               0.1                       6.8
# 3                  0               0.1                       6.8
# 4                  0               0.1                       6.9
# 5                  0               0.1                       6.9
#
#   Température bouilleur Température tête de colonne
# 1                    15                        16.9
# 2                  15.1                        16.9
# ...

# %%
df.tail()
# Out:
#       Temps puisance de chauffe puissance de prechauffage Taux de reflux  \
# 1163  12782                   0                        24             20
# 1164  12793                  80                        23              8
# 1165  12804                  60                        22              9
# 1166  12815                  18                        21              2
# 1167  12826                  99                        20             23
#
#      Débit alimentation Pertes de charges Température de préchauffe  \
# 1163               2.17               2.7                      78.9
# 1164               2.17               1.1                      79.1
# 1165               2.17               2.3                      79.5
# 1166               2.17               1.6                      79.8
# 1167               2.17               1.6                      80.1
#
#      Température bouilleur Température tête de colonne
# 1163                   109                       101.3
# ...

# %%
df.columns
# Out:
# Index(['Temps', 'puisance de chauffe', 'puissance de prechauffage',
#        'Taux de reflux', 'Débit alimentation', 'Pertes de charges',
#        'Température de préchauffe', 'Température bouilleur',
#        'Température tête de colonne'],
#       dtype='object')

# %%
for col in df.columns:
    df[col] = df[col].astype("float")

# %%
df2 = df.loc[df["Temps"] >= 2002]

# %%
df2.head()
# Out:
#       Temps  puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 183  2002.0                100.0                        2.0             8.0
# 184  2013.0                  0.0                        4.0            10.0
# 185  2024.0                 73.0                        5.0             4.0
# 186  2035.0                 70.0                        7.0            12.0
# 187  2046.0                 32.0                        9.0             7.0
#
#      Débit alimentation  Pertes de charges  Température de préchauffe  \
# 183                2.17                0.9                       85.3
# 184                2.17                2.6                       84.5
# 185                2.17                1.1                       83.9
# 186                2.17                2.2                       83.2
# 187                2.17                1.4                       82.7
#
#      Température bouilleur  Température tête de colonne
# ...

# %%
df2.drop('Temps',axis=1,inplace=True)
df2.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8068\2423671078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop('Temps',axis=1,inplace=True)
#      puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 183                100.0                        2.0             8.0
# 184                  0.0                        4.0            10.0
# 185                 73.0                        5.0             4.0
# 186                 70.0                        7.0            12.0
# 187                 32.0                        9.0             7.0
#
#      Débit alimentation  Pertes de charges  Température de préchauffe  \
# 183                2.17                0.9                       85.3
# 184                2.17                2.6                       84.5
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 985 entries, 183 to 1167
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   puisance de chauffe          985 non-null    float64
#  1   puissance de prechauffage    985 non-null    float64
#  2   Taux de reflux               985 non-null    float64
#  3   Débit alimentation           985 non-null    float64
#  4   Pertes de charges            985 non-null    float64
#  5   Température de préchauffe    985 non-null    float64
#  6   Température bouilleur        985 non-null    float64
#  7   Température tête de colonne  985 non-null    float64
# dtypes: float64(8)
# memory usage: 69.3 KB

# %%
df_fin = df2.loc[(df['Température tête de colonne'] <= 101.6) & (df['Température tête de colonne'] >= 101.4)]

# %%
df_fin.head()
# Out:
#      puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 183                100.0                        2.0             8.0
# 184                  0.0                        4.0            10.0
# 185                 73.0                        5.0             4.0
# 186                 70.0                        7.0            12.0
# 187                 32.0                        9.0             7.0
#
#      Débit alimentation  Pertes de charges  Température de préchauffe  \
# 183                2.17                0.9                       85.3
# 184                2.17                2.6                       84.5
# 185                2.17                1.1                       83.9
# 186                2.17                2.2                       83.2
# 187                2.17                1.4                       82.7
#
#      Température bouilleur  Température tête de colonne
# 183                  107.8                        101.6
# ...

# %%
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 946 entries, 183 to 1166
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   puisance de chauffe          946 non-null    float64
#  1   puissance de prechauffage    946 non-null    float64
#  2   Taux de reflux               946 non-null    float64
#  3   Débit alimentation           946 non-null    float64
#  4   Pertes de charges            946 non-null    float64
#  5   Température de préchauffe    946 non-null    float64
#  6   Température bouilleur        946 non-null    float64
#  7   Température tête de colonne  946 non-null    float64
# dtypes: float64(8)
# memory usage: 66.5 KB

# %%
df_fin.nunique()
# Out:
# puisance de chauffe             94
# puissance de prechauffage       46
# Taux de reflux                  25
# Débit alimentation               1
# Pertes de charges               26
# Température de préchauffe      113
# Température bouilleur           17
# Température tête de colonne      3
# dtype: int64

# %%
print(df_fin['Température tête de colonne'].value_counts())
# Out:
# 101.5    616
# 101.6    268
# 101.4     62
# Name: Température tête de colonne, dtype: int64

# %%
df_fin.reset_index(inplace=True, drop=True)

# %%
df_fin.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# 0                  107.8                        101.6
# ...

# %%
df_fin.to_csv('Comportement_normal_final.csv')

# %%
df_débit_min = pd.read_csv("Dys débit alimentation min.csv")
df_débit_min.head()
# Out:
#    Temps  Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0  10835                   15                          4               0
# 1  10846                  100                          6              10
# 2  10857                    5                          4               3
# 3  10868                   96                          4              14
# 4  10879                    0                          4              14
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                   0                1.7                       84.2
# 1                   0                1.6                       83.4
# 2                   0                2.0                       83.9
# 3                   0                1.4                       83.9
# 4                   0                2.9                       83.7
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                        101.7
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_comport = pd.read_csv('Comportement_normal_final.csv')
df_comport.head()
# Out:
#    Unnamed: 0  puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0           0                100.0                        2.0             8.0
# 1           1                  0.0                        4.0            10.0
# 2           2                 73.0                        5.0             4.0
# 3           3                 70.0                        7.0            12.0
# 4           4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# ...

# %%
df_comport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   946 non-null    int64
#  1   puisance de chauffe          946 non-null    float64
#  2   puissance de prechauffage    946 non-null    float64
#  3   Taux de reflux               946 non-null    float64
#  4   Débit alimentation           946 non-null    float64
#  5   Pertes de charges            946 non-null    float64
#  6   Température de préchauffe    946 non-null    float64
#  7   Température bouilleur        946 non-null    float64
#  8   Température tête de colonne  946 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 66.6 KB

# %%
df_débit_min = pd.read_csv('Dys débit alimentation min.csv')

# %%
df_débit_min.head()
# Out:
#    Temps  Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0  10835                   15                          4               0
# 1  10846                  100                          6              10
# 2  10857                    5                          4               3
# 3  10868                   96                          4              14
# 4  10879                    0                          4              14
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                   0                1.7                       84.2
# 1                   0                1.6                       83.4
# 2                   0                2.0                       83.9
# 3                   0                1.4                       83.9
# 4                   0                2.9                       83.7
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                        101.7
# ...

# %%
df_comport.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_comport.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# 0                  107.8                        101.6
# ...

# %%
df_débit_min.drop('Temps', axis=1, inplace=True)

# %%
df_débit_min.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                   15                          4               0
# 1                  100                          6              10
# 2                    5                          4               3
# 3                   96                          4              14
# 4                    0                          4              14
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                   0                1.7                       84.2
# 1                   0                1.6                       83.4
# 2                   0                2.0                       83.9
# 3                   0                1.4                       83.9
# 4                   0                2.9                       83.7
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                        101.7
# ...

# %%
df_débit_max = pd.read_csv('Dys débit alimentation max.csv')
df_pchauffe_min = pd.read_csv('Dys Puissance de chauffe min.csv')
df_pchauffe_max = pd.read_csv('Dys Puissance de chauffe max.csv')
df_pprechauffe_min = pd.read_csv('Dys Puissance de préchauffe min.csv')
df_pprechauffe_max = pd.read_csv('Dys Puissance de préchauffe max.csv')
df_trefulx_min = pd.read_csv('Dys taux de reflux min.csv')
df_treflux_max = pd.read_csv('Dys taux de reflux max.csv')

# %%
df_débit_max.head()
# Out:
#    Temps  Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0  10835                   65                         18               8
# 1  10846                  100                         17               8
# 2  10857                    0                         15              15
# 3  10868                   86                         15               6
# 4  10879                   66                         16              11
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                4.33                2.3                       80.2
# 1                4.33                0.9                       80.6
# 2                4.33                2.8                       81.0
# 3                4.33                1.1                       81.1
# 4                4.33                2.2                       80.8
#
#    Température bouilleur  Température tête de colonne
# 0                  109.5                        101.5
# ...

# %%
df_débit_max.drop('Temps', axis=1, inplace=True)

# %%
df_débit_max.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                   65                         18               8
# 1                  100                         17               8
# 2                    0                         15              15
# 3                   86                         15               6
# 4                   66                         16              11
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                4.33                2.3                       80.2
# 1                4.33                0.9                       80.6
# 2                4.33                2.8                       81.0
# 3                4.33                1.1                       81.1
# 4                4.33                2.2                       80.8
#
#    Température bouilleur  Température tête de colonne
# 0                  109.5                        101.5
# ...

# %%
df_list = [df_pchauffe_min, df_pchauffe_max, df_pprechauffe_min, df_pprechauffe_max, df_trefulx_min, df_treflux_max]

# %%
for df in df_list:
    df.drop('Temps', axis=1, inplace=True)

# %%
df_comport.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# 0                  107.8                        101.6
# ...

# %%
df_débit_min.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                   15                          4               0
# 1                  100                          6              10
# 2                    5                          4               3
# 3                   96                          4              14
# 4                    0                          4              14
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                   0                1.7                       84.2
# 1                   0                1.6                       83.4
# 2                   0                2.0                       83.9
# 3                   0                1.4                       83.9
# 4                   0                2.9                       83.7
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                        101.7
# ...

# %%
df_débit_max.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                   65                         18               8
# 1                  100                         17               8
# 2                    0                         15              15
# 3                   86                         15               6
# 4                   66                         16              11
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                4.33                2.3                       80.2
# 1                4.33                0.9                       80.6
# 2                4.33                2.8                       81.0
# 3                4.33                1.1                       81.1
# 4                4.33                2.2                       80.8
#
#    Température bouilleur  Température tête de colonne
# 0                  109.5                        101.5
# ...

# %%
df_pchauffe_min.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                    0                         20              14
# 1                    0                         22              38
# 2                    0                         23             100
# 3                    0                         23             100
# 4                    0                         26             100
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.6                       79.0
# 1                2.17                0.4                       78.5
# 2                2.17                0.3                       78.2
# 3                2.17                0.3                       77.9
# 4                2.17                0.3                       77.6
#
#    Température bouilleur  Température tête de colonne
# 0                  108.6                        101.4
# ...

# %%
df_pchauffe_max.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                  100                         33              19
# 1                  100                         35               8
# 2                  100                         37               2
# 3                  100                         38               1
# 4                  100                         38               4
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                1.4                       80.8
# 1                2.17                3.8                       80.8
# 2                2.17                6.0                       81.1
# 3                2.17                7.0                       81.3
# 4                2.17                9.3                       81.8
#
#    Température bouilleur  Température tête de colonne
# 0                  109.2                        101.4
# ...

# %%
df_pprechauffe_min.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                   31                         10              13
# 1                  100                         10              11
# 2                    0                         10               7
# 3                   94                         10              11
# 4                   26                         10              13
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                2.5                       74.2
# 1                2.17                0.9                       73.9
# 2                2.17                3.0                       73.7
# 3                2.17                1.1                       73.5
# 4                2.17                2.6                       73.4
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                        101.5
# ...

# %%
df_pprechauffe_max.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                    2                         90               3
# 1                    2                         90               3
# 2                  100                         90              10
# 3                    0                         90               8
# 4                  100                         90              10
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17              101.6                        2.1
# 1                2.17              101.6                        3.0
# 2                2.17              101.5                        0.9
# 3                2.17              101.5                        3.1
# 4                2.17              101.5                        0.9
#
#    Température bouilleur  Température tête de colonne
# 0                   80.5                        109.1
# ...

# %%
df_trefulx_min.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                  100                         13               0
# 1                  100                         17               0
# 2                    0                         18               0
# 3                  100                         20               0
# 4                    0                         22               0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                1.2                       80.5
# 1                2.17                1.3                       79.5
# 2                2.17                3.1                       79.0
# 3                2.17                1.0                       78.5
# 4                2.17                3.1                       78.1
#
#    Température bouilleur  Température tête de colonne
# 0                  107.7                        101.6
# ...

# %%
df_treflux_max.head()
# Out:
#    Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                   99                         12             100
# 1                  100                         12             100
# 2                    0                         11             100
# 3                   80                         11             100
# 4                   59                         12             100
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                1.6                       81.4
# 1                2.17                0.9                       81.5
# 2                2.17                2.6                       81.5
# 3                2.17                1.1                       81.4
# 4                2.17                2.3                       81.3
#
#    Température bouilleur  Température tête de colonne
# 0                  108.0                        101.6
# ...

# %%
df_comport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   puisance de chauffe          946 non-null    float64
#  1   puissance de prechauffage    946 non-null    float64
#  2   Taux de reflux               946 non-null    float64
#  3   Débit alimentation           946 non-null    float64
#  4   Pertes de charges            946 non-null    float64
#  5   Température de préchauffe    946 non-null    float64
#  6   Température bouilleur        946 non-null    float64
#  7   Température tête de colonne  946 non-null    float64
# dtypes: float64(8)
# memory usage: 59.2 KB

# %%
df_débit_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Puisance de chauffe          321 non-null    int64
#  1   Puissance de prechauffage    321 non-null    int64
#  2   Taux de reflux               321 non-null    int64
#  3   Débit alimentation           321 non-null    int64
#  4   Pertes de charges            321 non-null    float64
#  5   Température de préchauffe    321 non-null    float64
#  6   Température bouilleur        321 non-null    float64
#  7   Température tête de colonne  321 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 20.2 KB

# %%
df_débit_min.convert_dtypes
# Out:
# <bound method NDFrame.convert_dtypes of      Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                     15                          4               0
# 1                    100                          6              10
# 2                      5                          4               3
# 3                     96                          4              14
# 4                      0                          4              14
# ..                   ...                        ...             ...
# 316                   68                          7               0
# 317                   77                          6               0
# 318                   23                          6               0
# 319                   97                          6               0
# 320                    0                          5               0
#
#      Débit alimentation  Pertes de charges  Température de préchauffe  \
# ...

# %%
df_débit_max.convert_dtypes
# Out:
# <bound method NDFrame.convert_dtypes of      Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0                     65                         18               8
# 1                    100                         17               8
# 2                      0                         15              15
# 3                     86                         15               6
# 4                     66                         16              11
# ..                   ...                        ...             ...
# 205                    0                         31              12
# 206                  100                         30              22
# 207                    0                         29              17
# 208                  100                         28              19
# 209                   53                         27              19
#
#      Débit alimentation  Pertes de charges  Température de préchauffe  \
# ...

# %%
df_débit_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Puisance de chauffe          321 non-null    int64
#  1   Puissance de prechauffage    321 non-null    int64
#  2   Taux de reflux               321 non-null    int64
#  3   Débit alimentation           321 non-null    int64
#  4   Pertes de charges            321 non-null    float64
#  5   Température de préchauffe    321 non-null    float64
#  6   Température bouilleur        321 non-null    float64
#  7   Température tête de colonne  321 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 20.2 KB

# %%
df_débit_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Puisance de chauffe          210 non-null    int64
#  1   Puissance de prechauffage    210 non-null    int64
#  2   Taux de reflux               210 non-null    int64
#  3   Débit alimentation           210 non-null    float64
#  4   Pertes de charges            210 non-null    float64
#  5   Température de préchauffe    210 non-null    float64
#  6   Température bouilleur        210 non-null    float64
#  7   Température tête de colonne  210 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 13.2 KB

# %%
df_pchauffe_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   puisance de chauffe          95 non-null     int64
#  1   puissance de prechauffage    95 non-null     int64
#  2   Taux de reflux               95 non-null     int64
#  3   Débit alimentation           95 non-null     float64
#  4   Pertes de charges            95 non-null     float64
#  5   Température de préchauffe    95 non-null     float64
#  6   Température bouilleur        95 non-null     float64
#  7   Température tête de colonne  95 non-null     float64
# dtypes: float64(5), int64(3)
# memory usage: 6.1 KB

# %%
df_pchauffe_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   puisance de chauffe          92 non-null     int64
#  1   puissance de prechauffage    92 non-null     int64
#  2   Taux de reflux               92 non-null     int64
#  3   Débit alimentation           92 non-null     float64
#  4   Pertes de charges            92 non-null     float64
#  5   Température de préchauffe    92 non-null     float64
#  6   Température bouilleur        92 non-null     float64
#  7   Température tête de colonne  92 non-null     float64
# dtypes: float64(5), int64(3)
# memory usage: 5.9 KB

# %%
df_pprechauffe_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Puisance de chauffe          160 non-null    int64
#  1   Puissance de prechauffage    160 non-null    int64
#  2   Taux de reflux               160 non-null    int64
#  3   Débit alimentation           160 non-null    float64
#  4   Pertes de charges            160 non-null    float64
#  5   Température de préchauffe    160 non-null    float64
#  6   Température bouilleur        160 non-null    float64
#  7   Température tête de colonne  160 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 10.1 KB

# %%
df_pprechauffe_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Puisance de chauffe          131 non-null    int64
#  1   Puissance de prechauffage    131 non-null    int64
#  2   Taux de reflux               131 non-null    int64
#  3   Débit alimentation           131 non-null    float64
#  4   Pertes de charges            131 non-null    float64
#  5   Température de préchauffe    131 non-null    float64
#  6   Température bouilleur        131 non-null    float64
#  7   Température tête de colonne  131 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 8.3 KB

# %%
df_treflux_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Puisance de chauffe          206 non-null    float64
#  1   Puissance de prechauffage    206 non-null    float64
#  2   Taux de reflux               206 non-null    float64
#  3   Débit alimentation           206 non-null    float64
#  4   Pertes de charges            206 non-null    float64
#  5   Température de préchauffe    206 non-null    float64
#  6   Température bouilleur        206 non-null    float64
#  7   Température tête de colonne  206 non-null    float64
# dtypes: float64(8)
# memory usage: 13.0 KB

# %%
df_trefulx_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Puisance de chauffe          240 non-null    int64
#  1   Puissance de prechauffage    240 non-null    int64
#  2   Taux de reflux               240 non-null    int64
#  3   Débit alimentation           240 non-null    float64
#  4   Pertes de charges            240 non-null    float64
#  5   Température de préchauffe    240 non-null    float64
#  6   Température bouilleur        240 non-null    float64
#  7   Température tête de colonne  240 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 15.1 KB

# %%
frames = [df_comport, df_débit_min, df_débit_max, df_pchauffe_min, df_pchauffe_max, df_pprechauffe_min, df_pprechauffe_max, df_trefulx_min, df_treflux_max]

# %%
df_final = pd.concat(frames)

# %%
df_final.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne  Puisance de chauffe  \
# 0                  107.8                        101.6                  NaN
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2401 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   puisance de chauffe          1133 non-null   float64
#  1   puissance de prechauffage    1133 non-null   float64
#  2   Taux de reflux               2401 non-null   float64
#  3   Débit alimentation           2401 non-null   float64
#  4   Pertes de charges            2401 non-null   float64
#  5   Température de préchauffe    2401 non-null   float64
#  6   Température bouilleur        2401 non-null   float64
#  7   Température tête de colonne  2401 non-null   float64
#  8   Puisance de chauffe          1268 non-null   float64
#  9   Puissance de prechauffage    1268 non-null   float64
# dtypes: float64(10)
# memory usage: 206.3 KB
