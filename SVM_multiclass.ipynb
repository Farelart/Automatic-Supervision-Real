# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_nor = pd.read_csv('Comportement_normal_final.csv')

# %%
df_nor.head()
# Out:
#    Unnamed: 0  puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0           0                100.0                        2.0             8.0
# 1           1                  0.0                        4.0            10.0
# 2           2                 73.0                        5.0             4.0
# 3           3                 70.0                        7.0            12.0
# 4           4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# ...

# %%
df_nor.shape
# Out:
# (946, 9)

# %%
df_nor.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df_nor.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# 0                  107.8                        101.6
# ...

# %%
df_nor['Température tête de colonne']=0

# %%
df_nor.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_nor.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# 0                  107.8                            0
# ...

# %%
df_déb_min = pd.read_csv('Dys débit alimentation min.csv')

# %%
df_déb_min.drop('Temps', axis=1, inplace=True)

# %%
df_déb_min.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_déb_min.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                   15                          4               0
# 1                  100                          6              10
# 2                    5                          4               3
# 3                   96                          4              14
# 4                    0                          4              14
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                   0                1.7                       84.2
# 1                   0                1.6                       83.4
# 2                   0                2.0                       83.9
# 3                   0                1.4                       83.9
# 4                   0                2.9                       83.7
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                        101.7
# ...

# %%
"""df.loc[df['Température tête de colonne'] == 101.4, 'Température tête de colonne'] = 0
df.loc[df['Température tête de colonne'] == 101.5, 'Température tête de colonne'] = 0
df.loc[df['Température tête de colonne'] == 101.6, 'Température tête de colonne'] = 0"""
# Out:
# "df.loc[df['Température tête de colonne'] == 101.4, 'Température tête de colonne'] = 0\ndf.loc[df['Température tête de colonne'] == 101.5, 'Température tête de colonne'] = 0\ndf.loc[df['Température tête de colonne'] == 101.6, 'Température tête de colonne'] = 0"

# %%
df_déb_min['Température tête de colonne'] = 1

# %%
#df.loc[df['Débit alimentation'] > 2.17, 'Température tête de colonne'] = 2 #Dysfonctionnement Débit max

# %%
df_déb_min.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                   15                          4               0
# 1                  100                          6              10
# 2                    5                          4               3
# 3                   96                          4              14
# 4                    0                          4              14
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                   0                1.7                       84.2
# 1                   0                1.6                       83.4
# 2                   0                2.0                       83.9
# 3                   0                1.4                       83.9
# 4                   0                2.9                       83.7
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                            1
# ...

# %%
#df.loc[df['Débit alimentation'] ==0, 'Température tête de colonne'] = 1 #Dys Débit min

# %%
df_déb_max=pd.read_csv('Dys débit alimentation max.csv')

# %%
df_déb_max.head()
# Out:
#    Temps  Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0  10835                   65                         18               8
# 1  10846                  100                         17               8
# 2  10857                    0                         15              15
# 3  10868                   86                         15               6
# 4  10879                   66                         16              11
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                4.33                2.3                       80.2
# 1                4.33                0.9                       80.6
# 2                4.33                2.8                       81.0
# 3                4.33                1.1                       81.1
# 4                4.33                2.2                       80.8
#
#    Température bouilleur  Température tête de colonne
# 0                  109.5                        101.5
# ...

# %%
df_déb_max['Température tête de colonne']=2

# %%
df_déb_max.drop('Temps', axis=1, inplace=True)

# %%
df_déb_max.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_déb_max.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                   65                         18               8
# 1                  100                         17               8
# 2                    0                         15              15
# 3                   86                         15               6
# 4                   66                         16              11
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                4.33                2.3                       80.2
# 1                4.33                0.9                       80.6
# 2                4.33                2.8                       81.0
# 3                4.33                1.1                       81.1
# 4                4.33                2.2                       80.8
#
#    Température bouilleur  Température tête de colonne
# 0                  109.5                            2
# ...

# %%
df_chau_min = pd.read_csv('Dys Puissance de chauffe min.csv')

# %%
df_chau_min.head()
# Out:
#    Temps  puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0  10835                    0                         20              14
# 1  10846                    0                         22              38
# 2  10857                    0                         23             100
# 3  10868                    0                         23             100
# 4  10879                    0                         26             100
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.6                       79.0
# 1                2.17                0.4                       78.5
# 2                2.17                0.3                       78.2
# 3                2.17                0.3                       77.9
# 4                2.17                0.3                       77.6
#
#    Température bouilleur  Température tête de colonne
# 0                  108.6                        101.4
# ...

# %%
df_chau_min['Température tête de colonne']=3

# %%
df_chau_min.drop('Temps', axis=1, inplace=True)

# %%
df_chau_min.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_chau_min.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                    0                         20              14
# 1                    0                         22              38
# 2                    0                         23             100
# 3                    0                         23             100
# 4                    0                         26             100
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.6                       79.0
# 1                2.17                0.4                       78.5
# 2                2.17                0.3                       78.2
# 3                2.17                0.3                       77.9
# 4                2.17                0.3                       77.6
#
#    Température bouilleur  Température tête de colonne
# 0                  108.6                            3
# ...

# %%
df_chau_max=pd.read_csv('Dys Puissance de chauffe max.csv')

# %%
df_chau_max['Température tête de colonne']=4

# %%
df_chau_max.drop('Temps', axis=1, inplace=True)

# %%
df_nor.set_axis(df_chau_max.columns, axis=1,inplace=True)

# %%
df_chau_max.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                  100                         33              19
# 1                  100                         35               8
# 2                  100                         37               2
# 3                  100                         38               1
# 4                  100                         38               4
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                1.4                       80.8
# 1                2.17                3.8                       80.8
# 2                2.17                6.0                       81.1
# 3                2.17                7.0                       81.3
# 4                2.17                9.3                       81.8
#
#    Température bouilleur  Température tête de colonne
# 0                  109.2                            4
# ...

# %%
df_prech_min=pd.read_csv('Dys Puissance de préchauffe min.csv')

# %%
df_prech_min.head()
# Out:
#    Temps  Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0  10835                   31                         10              13
# 1  10846                  100                         10              11
# 2  10857                    0                         10               7
# 3  10868                   94                         10              11
# 4  10879                   26                         10              13
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                2.5                       74.2
# 1                2.17                0.9                       73.9
# 2                2.17                3.0                       73.7
# 3                2.17                1.1                       73.5
# 4                2.17                2.6                       73.4
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                        101.5
# ...

# %%
df_prech_min['Température tête de colonne']=5

# %%
df_prech_min.drop('Temps', axis=1, inplace=True)

# %%
df_prech_min.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_prech_min.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                   31                         10              13
# 1                  100                         10              11
# 2                    0                         10               7
# 3                   94                         10              11
# 4                   26                         10              13
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                2.5                       74.2
# 1                2.17                0.9                       73.9
# 2                2.17                3.0                       73.7
# 3                2.17                1.1                       73.5
# 4                2.17                2.6                       73.4
#
#    Température bouilleur  Température tête de colonne
# 0                  109.0                            5
# ...

# %%
df_prech_max=pd.read_csv('Dys Puissance de préchauffe max.csv')

# %%
df_prech_max.head()
# Out:
#    Temps  Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0  10835                    2                         90               3
# 1  10846                    2                         90               3
# 2  10857                  100                         90              10
# 3  10868                    0                         90               8
# 4  10879                  100                         90              10
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17              101.6                        2.1
# 1                2.17              101.6                        3.0
# 2                2.17              101.5                        0.9
# 3                2.17              101.5                        3.1
# 4                2.17              101.5                        0.9
#
#    Température bouilleur  Température tête de colonne
# 0                   80.5                        109.1
# ...

# %%
df_prech_max['Température tête de colonne']=6

# %%
df_prech_max.drop('Temps', axis=1, inplace=True)

# %%
df_prech_max.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_prech_max.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                    2                         90               3
# 1                    2                         90               3
# 2                  100                         90              10
# 3                    0                         90               8
# 4                  100                         90              10
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17              101.6                        2.1
# 1                2.17              101.6                        3.0
# 2                2.17              101.5                        0.9
# 3                2.17              101.5                        3.1
# 4                2.17              101.5                        0.9
#
#    Température bouilleur  Température tête de colonne
# 0                   80.5                            6
# ...

# %%
df_reflux_min=pd.read_csv('Dys taux de reflux min.csv')

# %%
df_reflux_min.head()
# Out:
#    Temps  Puisance de chauffe  Puissance de prechauffage  Taux de reflux  \
# 0  10835                  100                         13               0
# 1  10846                  100                         17               0
# 2  10857                    0                         18               0
# 3  10868                  100                         20               0
# 4  10879                    0                         22               0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                1.2                       80.5
# 1                2.17                1.3                       79.5
# 2                2.17                3.1                       79.0
# 3                2.17                1.0                       78.5
# 4                2.17                3.1                       78.1
#
#    Température bouilleur  Température tête de colonne
# 0                  107.7                        101.6
# ...

# %%
df_reflux_min['Température tête de colonne']=7

# %%
df_reflux_min.drop('Temps', axis=1, inplace=True)

# %%
df_reflux_min.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_reflux_min.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                  100                         13               0
# 1                  100                         17               0
# 2                    0                         18               0
# 3                  100                         20               0
# 4                    0                         22               0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                1.2                       80.5
# 1                2.17                1.3                       79.5
# 2                2.17                3.1                       79.0
# 3                2.17                1.0                       78.5
# 4                2.17                3.1                       78.1
#
#    Température bouilleur  Température tête de colonne
# 0                  107.7                            7
# ...

# %%
df_reflux_max=pd.read_csv('Dys taux de reflux max.csv')

# %%
df_reflux_max.drop('Temps', axis=1, inplace=True)

# %%
df_reflux_max['Température tête de colonne']=8

# %%
df_reflux_max.set_axis(df_nor.columns, axis=1,inplace=True)

# %%
df_reflux_max.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                   99                         12             100
# 1                  100                         12             100
# 2                    0                         11             100
# 3                   80                         11             100
# 4                   59                         12             100
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                1.6                       81.4
# 1                2.17                0.9                       81.5
# 2                2.17                2.6                       81.5
# 3                2.17                1.1                       81.4
# 4                2.17                2.3                       81.3
#
#    Température bouilleur  Température tête de colonne
# 0                  108.0                            8
# ...

# %%
frames=[df_nor,df_déb_min,df_déb_max,df_chau_min,df_chau_max,df_prech_min,df_prech_max,df_reflux_min,df_reflux_max]

# %%
df_final=pd.concat(frames,ignore_index=True)

# %%
df_final.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur  Température tête de colonne
# 0                  107.8                            0
# ...

# %%
df_final.shape
# Out:
# (2401, 8)

# %%
df_final.tail()
# Out:
#       puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 2396                100.0                       15.0           100.0
# 2397                100.0                       15.0           100.0
# 2398                100.0                       17.0           100.0
# 2399                100.0                       18.0           100.0
# 2400                  0.0                       18.0           100.0
#
#       Débit alimentation  Pertes de charges  Température de préchauffe  \
# 2396                2.17                0.3                       80.0
# 2397                2.17                0.3                       80.0
# 2398                2.17                0.3                       79.5
# 2399                2.17                0.3                       79.2
# 2400                2.17                0.3                       79.2
#
#       Température bouilleur  Température tête de colonne
# 2396                  108.4                            8
# ...

# %%
df_final.index.is_unique
# Out:
# True

# %%
df_final.columns.is_unique
# Out:
# True

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   puisance de chauffe          2401 non-null   float64
#  1   puissance de prechauffage    2401 non-null   float64
#  2   Taux de reflux               2401 non-null   float64
#  3   Débit alimentation           2401 non-null   float64
#  4   Pertes de charges            2401 non-null   float64
#  5   Température de préchauffe    2401 non-null   float64
#  6   Température bouilleur        2401 non-null   float64
#  7   Température tête de colonne  2401 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 150.2 KB

# %%
df_final.nunique()
# Out:
# puisance de chauffe            101
# puissance de prechauffage       49
# Taux de reflux                  39
# Débit alimentation               4
# Pertes de charges               94
# Température de préchauffe      239
# Température bouilleur          170
# Température tête de colonne      9
# dtype: int64

# %%
df_final['Température tête de colonne'].value_counts()
# Out:
# 0    946
# 1    321
# 7    240
# 2    210
# 8    206
# 6    160
# 5    131
# 4     95
# 3     92
# Name: Température tête de colonne, dtype: int64

# %%
df_final.to_csv('Dataset_multiclass.csv')

# %%
df_features = df_final.drop('Température tête de colonne', axis=1, inplace=False)

# %%
df_features.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                100.0                        2.0             8.0
# 1                  0.0                        4.0            10.0
# 2                 73.0                        5.0             4.0
# 3                 70.0                        7.0            12.0
# 4                 32.0                        9.0             7.0
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0                2.17                0.9                       85.3
# 1                2.17                2.6                       84.5
# 2                2.17                1.1                       83.9
# 3                2.17                2.2                       83.2
# 4                2.17                1.4                       82.7
#
#    Température bouilleur
# 0                  107.8
# 1                  107.8
# 2                  107.8
# 3                  107.9
# 4                  107.9

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()
df_sc = scale.fit_transform(df_features)

# %%
df_sc = pd.DataFrame(df_sc, columns = df_features.columns)
df_sc.head()
# Out:
#    puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0             1.052098                  -1.031008       -0.345286
# 1            -1.206039                  -0.930278       -0.280983
# 2             0.442401                  -0.879912       -0.473893
# 3             0.374657                  -0.779182       -0.216679
# 4            -0.483435                  -0.678452       -0.377438
#
#    Débit alimentation  Pertes de charges  Température de préchauffe  \
# 0            0.098819          -0.324148                   0.582409
# 1            0.098819          -0.255889                   0.542018
# 2            0.098819          -0.316117                   0.511724
# 3            0.098819          -0.271950                   0.476382
# 4            0.098819          -0.304072                   0.451138
#
#    Température bouilleur
# 0               0.055358
# 1               0.055358
# 2               0.055358
# 3               0.074960
# 4               0.074960

# %%
df_sc.describe().T
# Out:
#                             count          mean       std        min  \
# puisance de chauffe        2401.0  1.026529e-17  1.000208  -1.206039
# puissance de prechauffage  2401.0  1.468352e-16  1.000208  -1.131738
# Taux de reflux             2401.0 -1.517043e-15  1.000208  -0.602500
# Débit alimentation         2401.0  4.038026e-16  1.000208  -2.038086
# Pertes de charges          2401.0  8.680178e-16  1.000208  -0.352254
# Température de préchauffe  2401.0 -2.915711e-15  1.000208  -3.678847
# Température bouilleur      2401.0 -1.655058e-15  1.000208 -12.685400
#
#                                 25%       50%       75%       max
# puisance de chauffe       -1.206039  0.216587  1.052098  1.052098
# puissance de prechauffage -0.577721 -0.225165  0.127392  3.401131
# Taux de reflux            -0.506045 -0.345286 -0.216679  2.612674
# Débit alimentation         0.098819  0.098819  0.098819  2.235725
# Pertes de charges         -0.316117 -0.283996 -0.247858  3.719182
# ...

# %%
df_sc['TCOLONNE_class'] = df_final['Température tête de colonne']

# %%
df_sc.shape
# Out:
# (2401, 8)

# %%
df_sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   puisance de chauffe        2401 non-null   float64
#  1   puissance de prechauffage  2401 non-null   float64
#  2   Taux de reflux             2401 non-null   float64
#  3   Débit alimentation         2401 non-null   float64
#  4   Pertes de charges          2401 non-null   float64
#  5   Température de préchauffe  2401 non-null   float64
#  6   Température bouilleur      2401 non-null   float64
#  7   TCOLONNE_class             2401 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 150.2 KB

# %%
df_sc
# Out:
#       puisance de chauffe  puissance de prechauffage  Taux de reflux  \
# 0                1.052098                  -1.031008       -0.345286
# 1               -1.206039                  -0.930278       -0.280983
# 2                0.442401                  -0.879912       -0.473893
# 3                0.374657                  -0.779182       -0.216679
# 4               -0.483435                  -0.678452       -0.377438
# ...                   ...                        ...             ...
# 2396             1.052098                  -0.376260        2.612674
# 2397             1.052098                  -0.376260        2.612674
# 2398             1.052098                  -0.275530        2.612674
# 2399             1.052098                  -0.225165        2.612674
# 2400            -1.206039                  -0.225165        2.612674
#
#       Débit alimentation  Pertes de charges  Température de préchauffe  \
# ...

# %%
pd.crosstab(df_sc['TCOLONNE_class'], df_sc['TCOLONNE_class'], normalize = 'all')*100
# Out:
# TCOLONNE_class         0          1         2         3         4        5  \
# TCOLONNE_class
# 0               39.40025   0.000000  0.000000  0.000000  0.000000  0.00000
# 1                0.00000  13.369429  0.000000  0.000000  0.000000  0.00000
# 2                0.00000   0.000000  8.746356  0.000000  0.000000  0.00000
# 3                0.00000   0.000000  0.000000  3.831737  0.000000  0.00000
# 4                0.00000   0.000000  0.000000  0.000000  3.956685  0.00000
# 5                0.00000   0.000000  0.000000  0.000000  0.000000  5.45606
# 6                0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 7                0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 8                0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
#
# TCOLONNE_class        6         7         8
# TCOLONNE_class
# 0               0.00000  0.000000  0.000000
# 1               0.00000  0.000000  0.000000
# 2               0.00000  0.000000  0.000000
# ...

# %%
y = df_sc['TCOLONNE_class']
X = df_sc.drop('TCOLONNE_class', axis=1, inplace=False)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1000)

# %%
from sklearn.svm import SVC

# %%
SVM_linear_1 =  SVC(kernel='linear', C=1)
SVM_linear_1.fit(X_train, y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
y_hat = SVM_linear_1.predict(X_test)

# %%
predictions = pd.DataFrame({'y_test':y_test, 'y_hat':y_hat})
predictions.head()
# Out:
#       y_test  y_hat
# 157        0      0
# 618        0      0
# 359        0      0
# 1183       1      1
# 1003       1      1

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_hat)
# Out:
# array([[193,   0,   0,   0,   0,   0,   0,   1,   0],
#        [  0,  60,   0,   0,   0,   0,   0,   0,   0],
#        [  0,   0,  45,   0,   0,   0,   0,   0,   0],
#        [  0,   0,   0,  21,   0,   0,   0,   0,   2],
#        [  2,   0,   0,   0,  14,   0,   0,   0,   0],
#        [  0,   0,   0,   0,   0,  21,   0,   0,   0],
#        [  0,   0,   0,   0,   0,   0,  26,   0,   0],
#        [  0,   0,   0,   0,   0,   0,   0,  59,   0],
#        [  0,   0,   0,   0,   0,   0,   0,   0,  37]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      0.91      0.95        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       0.98      1.00      0.99        59
#            8       0.95      1.00      0.97        37
#
#     accuracy                           0.99       481
#    macro avg       0.99      0.98      0.98       481
# weighted avg       0.99      0.99      0.99       481

# %%
SVM_rbf_1 =  SVC(kernel='rbf', C=1, gamma=0.1)
SVM_rbf_1.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=0.1)

# %%
y_hat_rbf_1 = SVM_rbf_1.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_hat_rbf_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      0.87      0.93        23
#            4       1.00      0.81      0.90        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       0.93      1.00      0.96        37
#
#     accuracy                           0.99       481
#    macro avg       0.99      0.96      0.98       481
# weighted avg       0.99      0.99      0.99       481

# %%
SVM_poly_1 =  SVC(kernel='poly', C=1, gamma=0.1)
SVM_poly_1.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=0.1, kernel='poly')

# %%
y_hat_poly_1 = SVM_poly_1.predict(X_test)
print(classification_report(y_test, y_hat_poly_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      0.87      0.93        23
#            4       0.00      0.00      0.00        16
#            5       0.00      0.00      0.00        21
#            6       1.00      1.00      1.00        26
#            7       0.00      0.00      0.00        59
#            8       0.93      1.00      0.96        37
#
#     accuracy                           0.79       481
#    macro avg       0.62      0.65      0.63       481
# weighted avg       0.66      0.79      0.71       481
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
SVM_linear_2 =  SVC(kernel='linear', C=10)
SVM_linear_2.fit(X_train, y_train)
y_hat_linear_2 = SVM_linear_2.predict(X_test)
print(classification_report(y_test, y_hat_linear_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           1.00       481
#    macro avg       1.00      0.99      0.99       481
# weighted avg       1.00      1.00      1.00       481

# %%
SVM_rbf_2 = SVC(kernel='rbf', C=10, gamma=0.3)
SVM_rbf_2.fit(X_train, y_train)
y_hat_rbf_2 = SVM_rbf_2.predict(X_test)
print(classification_report(y_test, y_hat_rbf_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       0.98      1.00      0.99        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           0.99       481
#    macro avg       1.00      0.99      0.99       481
# weighted avg       0.99      0.99      0.99       481

# %%
SVM_poly_2 = SVC(kernel='poly', C=10, gamma=0.3)
SVM_poly_2.fit(X_train, y_train)
y_hat_poly_2 = SVM_poly_2.predict(X_test)
print(classification_report(y_test, y_hat_poly_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       0.98      1.00      0.99        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           0.99       481
#    macro avg       1.00      0.99      0.99       481
# weighted avg       0.99      0.99      0.99       481

# %%
SVM_linear_3 =  SVC(kernel='linear', C=100)
SVM_linear_3.fit(X_train, y_train)
y_hat_linear_3 = SVM_linear_3.predict(X_test)
print(classification_report(y_test, y_hat_linear_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           1.00       481
#    macro avg       1.00      0.99      0.99       481
# weighted avg       1.00      1.00      1.00       481

# %%
SVM_rbf_3 = SVC(kernel='rbf', C=100, gamma=0.6)
SVM_rbf_3.fit(X_train, y_train)
y_hat_rbf_3 = SVM_rbf_3.predict(X_test)
print(classification_report(y_test, y_hat_rbf_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.94      0.97        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           1.00       481
#    macro avg       1.00      0.99      1.00       481
# weighted avg       1.00      1.00      1.00       481

# %%
SVM_poly_3 = SVC(kernel='poly', C=100, gamma=0.6)
SVM_poly_3.fit(X_train, y_train)
y_hat_poly_3 = SVM_poly_3.predict(X_test)
print(classification_report(y_test, y_hat_poly_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           1.00       481
#    macro avg       1.00      0.99      0.99       481
# weighted avg       1.00      1.00      1.00       481

# %%
SVM_linear_4 =  SVC(kernel='linear', C=1000)
SVM_linear_4.fit(X_train, y_train)
y_hat_linear_4 = SVM_linear_4.predict(X_test)
print(classification_report(y_test, y_hat_linear_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           1.00       481
#    macro avg       1.00      0.99      0.99       481
# weighted avg       1.00      1.00      1.00       481

# %%
SVM_rbf_4 = SVC(kernel='rbf', C=1000, gamma=0.9)
SVM_rbf_4.fit(X_train, y_train)
y_hat_rbf_4 = SVM_rbf_4.predict(X_test)
print(classification_report(y_test, y_hat_rbf_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.94      0.97        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           1.00       481
#    macro avg       1.00      0.99      1.00       481
# weighted avg       1.00      1.00      1.00       481

# %%
SVM_poly_4 = SVC(kernel='poly', C=1000, gamma=0.9)
SVM_poly_4.fit(X_train, y_train)
y_hat_poly_4 = SVM_poly_4.predict(X_test)
print(classification_report(y_test, y_hat_poly_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       194
#            1       1.00      1.00      1.00        60
#            2       1.00      1.00      1.00        45
#            3       1.00      1.00      1.00        23
#            4       1.00      0.88      0.93        16
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        59
#            8       1.00      1.00      1.00        37
#
#     accuracy                           1.00       481
#    macro avg       1.00      0.99      0.99       481
# weighted avg       1.00      1.00      1.00       481
